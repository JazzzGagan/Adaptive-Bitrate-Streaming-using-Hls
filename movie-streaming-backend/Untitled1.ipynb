# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Step 1: Combine text
def combineText(movie):
    return movie['overviews'] + " " + movie['genres']

watched_Text = [combineText(movie) for movie in watched_texts]
candidate_Text = [combineText(movie) for movie in candidate_texts]
all_texts = watched_Text + candidate_Text

# Step 2: Vectorize using TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_texts)

# Step 3: Separate vectors
n_watched = len(watched_Text)
watched_vectors = tfidf_matrix[:n_watched]
candidate_vectors = tfidf_matrix[n_watched:]

# Step 4: Compute cosine similarity
similarity = cosine_similarity(candidate_vectors, watched_vectors)

# Step 5: Display matrix
df = pd.DataFrame(
    similarity,
    index=[f"Candidate {i+1}" for i in range(len(candidate_Text))],
    columns=[f"Watched {i+1}" for i in range(len(watched_Text))]
)

print(df)
# Out:
#               Watched 1  Watched 2  Watched 3  Watched 4  Watched 5  \
# Candidate 1    0.104362   0.079505   0.071733   0.112202   0.060644
# Candidate 2    0.046925   0.061885   0.046724   0.059300   0.033664
# Candidate 3    0.044117   0.077761   0.029840   0.088985   1.000000
# Candidate 4    0.103056   0.054424   0.031218   0.157660   0.130926
# Candidate 5    0.110277   0.060056   0.090765   0.123907   0.115396
# Candidate 6    0.045746   0.032053   0.042731   0.085393   0.049571
# Candidate 7    0.117039   0.152298   0.023907   0.125465   0.081653
# Candidate 8    0.089633   0.042548   0.085309   0.068584   0.039684
# Candidate 9    0.020574   0.039121   0.020815   0.078565   0.000000
# Candidate 10   0.067595   0.111070   0.080492   0.137880   0.117949
# Candidate 11   0.112730   0.067529   0.041017   0.094234   0.064632
# Candidate 12   0.086694   0.053146   0.064835   0.132058   0.097329
# Candidate 13   0.009139   0.079967   0.033501   0.118724   0.020429
# Candidate 14   0.081326   0.082432   0.046901   0.120024   0.106329
# Candidate 15   0.058328   0.083335   0.054423   0.103127   0.043000
# Candidate 16   0.083834   0.093351   0.065375   0.086644   0.091086
# Candidate 17   0.062308   0.057322   0.070725   0.138102   0.075043
# Candidate 18   0.064152   0.010131   0.022532   0.086265   0.084154
# Candidate 19   0.038232   0.055834   0.079109   0.038414   0.066046
# Candidate 20   0.059916   0.176681   0.061461   0.128542   0.109741
#
#               Watched 6  Watched 7  Watched 8  Watched 9  Watched 10  \
# Candidate 1    0.102845   0.088799   0.115640   0.016130    1.000000
# Candidate 2    0.045021   0.032206   0.055011   0.060110    0.049673
# Candidate 3    0.115396   0.128579   0.117949   0.000000    0.060644
# Candidate 4    0.185221   0.165124   0.130464   0.013349    0.136330
# Candidate 5    1.000000   0.089754   0.070303   0.049379    0.102845
# Candidate 6    0.062807   0.088086   0.023591   0.004553    0.034260
# Candidate 7    0.080068   0.117019   0.139158   0.025344    0.091058
# Candidate 8    0.089497   0.032388   0.067039   0.033472    0.101078
# Candidate 9    0.049379   0.000000   0.075498   1.000000    0.016130
# Candidate 10   0.070303   0.072373   1.000000   0.075498    0.115640
# Candidate 11   0.108342   0.064796   0.063027   0.013399    0.090195
# Candidate 12   0.123268   0.116326   0.096043   0.080998    0.091244
# Candidate 13   0.063895   0.028621   0.101403   0.113730    0.028787
# Candidate 14   0.073611   0.089769   0.104747   0.067246    0.086457
# Candidate 15   0.052507   0.038336   0.102123   0.104156    0.059899
# Candidate 16   0.118254   0.064150   0.127532   0.036000    0.155825
# Candidate 17   0.079128   0.137691   0.090258   0.087734    0.113693
# Candidate 18   0.085533   0.121574   0.050129   0.000000    0.063797
# Candidate 19   0.017971   0.024337   0.102271   0.021837    0.064393
# Candidate 20   0.118934   0.070416   0.084079   0.039723    0.103190
#
#               Watched 11  Watched 12
# Candidate 1     0.081906    0.090003
# Candidate 2     0.015445    0.040798
# Candidate 3     0.056910    0.125748
# Candidate 4     0.118786    0.229953
# Candidate 5     0.099958    0.157342
# Candidate 6     0.058909    0.074865
# Candidate 7     0.082074    0.097484
# Candidate 8     0.056819    0.069548
# Candidate 9     0.026696    0.005991
# Candidate 10    0.065896    0.107734
# Candidate 11    0.063051    0.130319
# Candidate 12    0.100901    0.139121
# Candidate 13    0.006352    0.045692
# Candidate 14    0.193537    0.067690
# Candidate 15    0.052144    0.075219
# Candidate 16    0.101877    0.085549
# Candidate 17    0.072440    0.096680
# Candidate 18    0.088727    0.095769
# Candidate 19    0.032911    0.054412
# Candidate 20    0.063916    0.095007
